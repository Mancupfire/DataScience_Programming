# %%
import panda as pd

# %%
file_path = "file_path = "IAQ Baqubah Teaching Hospital .csv"
df = pd.read_csv(file_path)

# Display basic info
print(df.info())
df.head()"
df = pd.read_csv(file_path)

# Display basic info
print(df.info())
df.head()
